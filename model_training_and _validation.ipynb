# %%
import time
import torch
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
import torchvision
from torch import nn
from torch.nn.utils.rnn import pack_padded_sequence
from nltk.translate.bleu_score import corpus_bleu
from torch.utils.data import Dataset
import h5py
import json
import os
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
from model import Encoder,Attention,DecoderWithAttention
from utils import clip_gradient,adjust_learning_rate,accuracy,save_checkpoint,AverageMeter,CaptionDataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# !nvidia-smi
# Out:
# Sun Apr 17 18:19:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.91.03    Driver Version: 460.91.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla M40 24GB      Off  | 00000000:04:00.0 Off |                    0 |
# | N/A   37C    P8    15W / 250W |      3MiB / 22945MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla M40 24GB      Off  | 00000000:82:00.0 Off |                    0 |
# | N/A   39C    P8    17W / 250W |      3MiB / 22945MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# TRAINING AND VALIDATION

# %%
data_folder = 'dataset/'  # folder with data files saved by create_input_files.py
data_name = 'coco_5_cap_per_img_5_min_word_freq'  # base name shared by data files

# %%
# Model parameters
emb_dim = 512  # dimension of word embeddings
attention_dim = 512  # dimension of attention linear layers
decoder_dim = 512  # dimension of decoder RNN
dropout = 0.5
cudnn.benchmark = True  # set to true only if inputs to model are fixed size; otherwise lot of computational overhead

# %%
# Training parameters
start_epoch = 0
epochs = 120  # number of epochs to train for (if early stopping is not triggered)
epochs_since_improvement = 0  # keeps track of number of epochs since there's been an improvement in validation BLEU
batch_size = 32
workers = 1  # for data-loading; right now, only 1 works with h5py
encoder_lr = 1e-4  # learning rate for encoder if fine-tuning
decoder_lr = 4e-4  # learning rate for decoder
grad_clip = 5.  # clip gradients at an absolute value of
alpha_c = 1.  # regularization parameter for 'doubly stochastic attention', as in the paper
best_bleu4 = 0.  # BLEU-4 score right now
print_freq = 100  # print training/validation stats every __ batches
fine_tune_encoder = False  # fine-tune encoder?
checkpoint = None  # path to checkpoint, None if none

# %%
def train(train_loader, encoder, decoder, criterion, encoder_optimizer, decoder_optimizer, epoch):
    decoder.train()  # train mode (dropout and batchnorm is used)
    encoder.train()

    batch_time = AverageMeter()  # forward prop. + back prop. time
    data_time = AverageMeter()  # data loading time
    losses = AverageMeter()  # loss (per word decoded)
    top5accs = AverageMeter()  # top5 accuracy

    start = time.time()

    # Batches
    for i, (imgs, caps, caplens) in enumerate(train_loader):
        data_time.update(time.time() - start)

        # Move to GPU, if available
        imgs = imgs.to(device)
        caps = caps.to(device)
        caplens = caplens.to(device)

        # Forward prop.
        imgs = encoder(imgs)
        scores, caps_sorted, decode_lengths, alphas, sort_ind = decoder(imgs, caps, caplens)

        # Since we decoded starting with <start>, the targets are all words after <start>, up to <end>
        targets = caps_sorted[:, 1:]

        # Remove timesteps that we didn't decode at, or are pads
        # pack_padded_sequence is an easy trick to do this
        
        scores = pack_padded_sequence(scores, decode_lengths, batch_first=True)[0]
        targets = pack_padded_sequence(targets, decode_lengths, batch_first=True)[0]

        # Calculate loss
        loss = criterion(scores, targets)

        # Add doubly stochastic attention regularization
        loss += alpha_c * ((1. - alphas.sum(dim=1)) ** 2).mean()

        # Back prop.
        decoder_optimizer.zero_grad()
        if encoder_optimizer is not None:
            encoder_optimizer.zero_grad()
        loss.backward()

        # Clip gradients
        if grad_clip is not None:
            clip_gradient(decoder_optimizer, grad_clip)
            if encoder_optimizer is not None:
                clip_gradient(encoder_optimizer, grad_clip)

        # Update weights
        decoder_optimizer.step()
        if encoder_optimizer is not None:
            encoder_optimizer.step()

        # Keep track of metrics
        top5 = accuracy(scores, targets, 5)
        losses.update(loss.item(), sum(decode_lengths))
        top5accs.update(top5, sum(decode_lengths))
        batch_time.update(time.time() - start)

        start = time.time()

        # Print status
        if i % print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Batch Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Data Load Time {data_time.val:.3f} ({data_time.avg:.3f})\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Top-5 Accuracy {top5.val:.3f} ({top5.avg:.3f})'.format(epoch, i, len(train_loader),
                                                                          batch_time=batch_time,
                                                                          data_time=data_time, loss=losses,
                                                                          top5=top5accs))

# %%
def validate(val_loader, encoder, decoder, criterion):
    """
    Performs one epoch's validation.

    :param val_loader: DataLoader for validation data.
    :param encoder: encoder model
    :param decoder: decoder model
    :param criterion: loss layer
    :return: BLEU-4 score
    """
    decoder.eval()  # eval mode (no dropout or batchnorm)
    if encoder is not None:
        encoder.eval()

    batch_time = AverageMeter()
    losses = AverageMeter()
    top5accs = AverageMeter()

    start = time.time()

    references = list()  # references (true captions) for calculating BLEU-4 score
    hypotheses = list()  # hypotheses (predictions)

    # explicitly disable gradient calculation to avoid CUDA memory error
    # solves the issue #57
    with torch.no_grad():
        # Batches
        for i, (imgs, caps, caplens, allcaps) in enumerate(val_loader):

            # Move to device, if available
            imgs = imgs.to(device)
            caps = caps.to(device)
            caplens = caplens.to(device)

            # Forward prop.
            if encoder is not None:
                imgs = encoder(imgs)
            scores, caps_sorted, decode_lengths, alphas, sort_ind = decoder(imgs, caps, caplens)

            # Since we decoded starting with <start>, the targets are all words after <start>, up to <end>
            targets = caps_sorted[:, 1:]

            # Remove timesteps that we didn't decode at, or are pads
            # pack_padded_sequence is an easy trick to do this
            scores_copy = scores.clone()
            scores = pack_padded_sequence(scores, decode_lengths, batch_first=True)[0]
            targets = pack_padded_sequence(targets, decode_lengths, batch_first=True)[0]

            # Calculate loss
            loss = criterion(scores, targets)

            # Add doubly stochastic attention regularization
            loss += alpha_c * ((1. - alphas.sum(dim=1)) ** 2).mean()

            # Keep track of metrics
            losses.update(loss.item(), sum(decode_lengths))
            top5 = accuracy(scores, targets, 5)
            top5accs.update(top5, sum(decode_lengths))
            batch_time.update(time.time() - start)

            start = time.time()

            if i % print_freq == 0:
                print('Validation: [{0}/{1}]\t'
                      'Batch Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                      'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                      'Top-5 Accuracy {top5.val:.3f} ({top5.avg:.3f})\t'.format(i, len(val_loader), batch_time=batch_time,
                                                                                loss=losses, top5=top5accs))

            # Store references (true captions), and hypothesis (prediction) for each image
            # If for n images, we have n hypotheses, and references a, b, c... for each image, we need -
            # references = [[ref1a, ref1b, ref1c], [ref2a, ref2b], ...], hypotheses = [hyp1, hyp2, ...]

            # References
            allcaps = allcaps[sort_ind]  # because images were sorted in the decoder
            for j in range(allcaps.shape[0]):
                img_caps = allcaps[j].tolist()
                img_captions = list(
                    map(lambda c: [w for w in c if w not in {word_map['<start>'], word_map['<pad>']}],
                        img_caps))  # remove <start> and pads
                references.append(img_captions)

            # Hypotheses
            _, preds = torch.max(scores_copy, dim=2)
            preds = preds.tolist()
            temp_preds = list()
            for j, p in enumerate(preds):
                temp_preds.append(preds[j][:decode_lengths[j]])  # remove pads
            preds = temp_preds
            hypotheses.extend(preds)

            assert len(references) == len(hypotheses)

        # Calculate BLEU-4 scores
        bleu4 = corpus_bleu(references, hypotheses)

        print(
            '\n * LOSS - {loss.avg:.3f}, TOP-5 ACCURACY - {top5.avg:.3f}, BLEU-4 - {bleu}\n'.format(
                loss=losses,
                top5=top5accs,
                bleu=bleu4))

    return bleu4

# %%
def main():
    """
    Training and validation.
    """

    global best_bleu4, epochs_since_improvement, checkpoint, start_epoch, fine_tune_encoder, data_name, word_map

    # Read word map
    word_map_file = os.path.join(data_folder, 'WORDMAP_' + data_name + '.json')
    with open(word_map_file, 'r') as j:
        word_map = json.load(j)
        
    checkpoint = "checkpoint_coco_5_cap_per_img_5_min_word_freq.pth.tar"

    # Initialize / load checkpoint
    if checkpoint is None:
        decoder = DecoderWithAttention(attention_dim=attention_dim,
                                       embed_dim=emb_dim,
                                       decoder_dim=decoder_dim,
                                       vocab_size=len(word_map),
                                       dropout=dropout)
        decoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, decoder.parameters()),
                                             lr=decoder_lr)
        encoder = Encoder()
        encoder.fine_tune(fine_tune_encoder)
        encoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()),
                                             lr=encoder_lr) if fine_tune_encoder else None

    else:
        checkpoint = torch.load(checkpoint)
        start_epoch = checkpoint['epoch'] + 1
        epochs_since_improvement = checkpoint['epochs_since_improvement']
        best_bleu4 = checkpoint['bleu-4']
        decoder = checkpoint['decoder']
        decoder_optimizer = checkpoint['decoder_optimizer']
        encoder = checkpoint['encoder']
        encoder_optimizer = checkpoint['encoder_optimizer']
        if fine_tune_encoder is True and encoder_optimizer is None:
            encoder.fine_tune(fine_tune_encoder)
            encoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()),
                                                 lr=encoder_lr)

    # Move to GPU, if available
    decoder = decoder.to(device)
    encoder = encoder.to(device)

    # Loss function
    criterion = nn.CrossEntropyLoss().to(device)

    # Custom dataloaders
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
    train_loader = torch.utils.data.DataLoader(
        CaptionDataset(data_folder, data_name, 'TRAIN', transform=transforms.Compose([normalize])),
        batch_size=batch_size, shuffle=True, num_workers=workers, pin_memory=True)
    val_loader = torch.utils.data.DataLoader(
        CaptionDataset(data_folder, data_name, 'VAL', transform=transforms.Compose([normalize])),
        batch_size=batch_size, shuffle=True, num_workers=workers, pin_memory=True)

    # Epochs
    for epoch in range(start_epoch, epochs):

        # Decay learning rate if there is no improvement for 8 consecutive epochs, and terminate training after 20
        if epochs_since_improvement == 20:
            break
        if epochs_since_improvement > 0 and epochs_since_improvement % 8 == 0:
            adjust_learning_rate(decoder_optimizer, 0.8)
            if fine_tune_encoder:
                adjust_learning_rate(encoder_optimizer, 0.8)

        # One epoch's training
        train(train_loader=train_loader,
              encoder=encoder,
              decoder=decoder,
              criterion=criterion,
              encoder_optimizer=encoder_optimizer,
              decoder_optimizer=decoder_optimizer,
              epoch=epoch)

        # One epoch's validation
        recent_bleu4 = validate(val_loader=val_loader,
                                encoder=encoder,
                                decoder=decoder,
                                criterion=criterion)

        # Check if there was an improvement
        is_best = recent_bleu4 > best_bleu4
        best_bleu4 = max(recent_bleu4, best_bleu4)
        if not is_best:
            epochs_since_improvement += 1
            print("\nEpochs since last improvement: %d\n" % (epochs_since_improvement,))
        else:
            epochs_since_improvement = 0

        # Save checkpoint
        state = {'epoch': epoch,
             'epochs_since_improvement': epochs_since_improvement,
             'bleu-4': recent_bleu4,
             'encoder': encoder,
             'decoder': decoder,
             'encoder_optimizer': encoder_optimizer,
             'decoder_optimizer': decoder_optimizer}
        filename = 'checkpoint_' + data_name + '.pth.tar'
        torch.save(state, filename)
        # If this checkpoint is the best so far, store a copy so it doesn't get overwritten by a worse checkpoint
        if is_best:
            torch.save(state, 'BEST_' + filename)

# %%
main()
# Out:
# Epoch: [28][0/17702]	Batch Time 2.455 (2.455)	Data Load Time 0.965 (0.965)	Loss 3.4412 (3.4412)	Top-5 Accuracy 71.316 (71.316)
# Epoch: [28][100/17702]	Batch Time 0.483 (0.476)	Data Load Time 0.001 (0.014)	Loss 3.6596 (3.3973)	Top-5 Accuracy 67.989 (71.704)
# Epoch: [28][200/17702]	Batch Time 0.432 (0.468)	Data Load Time 0.001 (0.009)	Loss 3.2963 (3.3828)	Top-5 Accuracy 77.067 (71.959)
# Epoch: [28][300/17702]	Batch Time 0.459 (0.467)	Data Load Time 0.026 (0.008)	Loss 3.1688 (3.3789)	Top-5 Accuracy 75.798 (71.979)
# Epoch: [28][400/17702]	Batch Time 0.469 (0.464)	Data Load Time 0.001 (0.007)	Loss 3.3081 (3.3772)	Top-5 Accuracy 73.278 (71.949)
# Epoch: [28][500/17702]	Batch Time 0.461 (0.464)	Data Load Time 0.001 (0.006)	Loss 3.4517 (3.3759)	Top-5 Accuracy 69.672 (71.923)
# Epoch: [28][600/17702]	Batch Time 0.439 (0.462)	Data Load Time 0.001 (0.006)	Loss 3.2826 (3.3765)	Top-5 Accuracy 73.879 (71.939)
# Epoch: [28][700/17702]	Batch Time 0.453 (0.462)	Data Load Time 0.001 (0.006)	Loss 3.5785 (3.3771)	Top-5 Accuracy 68.169 (71.920)
# Epoch: [28][800/17702]	Batch Time 0.442 (0.463)	Data Load Time 0.001 (0.006)	Loss 3.6198 (3.3784)	Top-5 Accuracy 71.671 (71.924)
# Epoch: [28][900/17702]	Batch Time 0.394 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.2740 (3.3778)	Top-5 Accuracy 71.585 (71.910)
# Epoch: [28][1000/17702]	Batch Time 0.403 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.4803 (3.3792)	Top-5 Accuracy 69.003 (71.899)
# Epoch: [28][1100/17702]	Batch Time 0.437 (0.461)	Data Load Time 0.001 (0.005)	Loss 3.2271 (3.3778)	Top-5 Accuracy 73.164 (71.920)
# Epoch: [28][1200/17702]	Batch Time 0.456 (0.462)	Data Load Time 0.001 (0.005)	Loss 3.4947 (3.3797)	Top-5 Accuracy 71.543 (71.909)
# Epoch: [28][1300/17702]	Batch Time 0.444 (0.461)	Data Load Time 0.001 (0.005)	Loss 3.3274 (3.3812)	Top-5 Accuracy 70.248 (71.886)
# Epoch: [28][1400/17702]	Batch Time 0.605 (0.461)	Data Load Time 0.014 (0.005)	Loss 3.4901 (3.3816)	Top-5 Accuracy 72.074 (71.882)
# Epoch: [28][1500/17702]	Batch Time 0.414 (0.461)	Data Load Time 0.014 (0.005)	Loss 3.4827 (3.3820)	Top-5 Accuracy 72.678 (71.876)
# Epoch: [28][1600/17702]	Batch Time 0.500 (0.461)	Data Load Time 0.014 (0.005)	Loss 3.1762 (3.3832)	Top-5 Accuracy 75.584 (71.879)
# Epoch: [28][1700/17702]	Batch Time 0.473 (0.462)	Data Load Time 0.001 (0.005)	Loss 3.4514 (3.3845)	Top-5 Accuracy 72.093 (71.865)
# Epoch: [28][1800/17702]	Batch Time 0.391 (0.462)	Data Load Time 0.001 (0.005)	Loss 3.5224 (3.3839)	Top-5 Accuracy 72.911 (71.878)
# Epoch: [28][1900/17702]	Batch Time 0.403 (0.461)	Data Load Time 0.001 (0.005)	Loss 3.3233 (3.3834)	Top-5 Accuracy 72.895 (71.877)
# Epoch: [28][2000/17702]	Batch Time 0.451 (0.462)	Data Load Time 0.001 (0.005)	Loss 3.2888 (3.3839)	Top-5 Accuracy 76.455 (71.868)
# Epoch: [28][2100/17702]	Batch Time 0.433 (0.462)	Data Load Time 0.001 (0.005)	Loss 3.3893 (3.3840)	Top-5 Accuracy 70.390 (71.874)
# Epoch: [28][2200/17702]	Batch Time 0.497 (0.462)	Data Load Time 0.001 (0.005)	Loss 3.4199 (3.3841)	Top-5 Accuracy 74.795 (71.854)
# Epoch: [28][2300/17702]	Batch Time 0.398 (0.462)	Data Load Time 0.001 (0.005)	Loss 3.5160 (3.3833)	Top-5 Accuracy 73.475 (71.873)
# Epoch: [28][2400/17702]	Batch Time 0.511 (0.462)	Data Load Time 0.001 (0.005)	Loss 3.4950 (3.3839)	Top-5 Accuracy 69.189 (71.863)
# Epoch: [28][2500/17702]	Batch Time 0.457 (0.462)	Data Load Time 0.001 (0.005)	Loss 3.5647 (3.3845)	Top-5 Accuracy 69.577 (71.854)
# Epoch: [28][2600/17702]	Batch Time 0.467 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.3028 (3.3843)	Top-5 Accuracy 74.725 (71.859)
# Epoch: [28][2700/17702]	Batch Time 0.467 (0.463)	Data Load Time 0.014 (0.005)	Loss 3.3175 (3.3853)	Top-5 Accuracy 71.579 (71.853)
# Epoch: [28][2800/17702]	Batch Time 0.505 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.4267 (3.3858)	Top-5 Accuracy 74.095 (71.855)
# Epoch: [28][2900/17702]	Batch Time 0.459 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.2307 (3.3859)	Top-5 Accuracy 74.095 (71.852)
# Epoch: [28][3000/17702]	Batch Time 0.543 (0.463)	Data Load Time 0.005 (0.005)	Loss 3.3491 (3.3868)	Top-5 Accuracy 73.925 (71.843)
# Epoch: [28][3100/17702]	Batch Time 0.453 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.2563 (3.3870)	Top-5 Accuracy 73.458 (71.839)
# Epoch: [28][3200/17702]	Batch Time 0.438 (0.464)	Data Load Time 0.026 (0.005)	Loss 3.5176 (3.3870)	Top-5 Accuracy 68.392 (71.840)
# Epoch: [28][3300/17702]	Batch Time 0.425 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.3103 (3.3870)	Top-5 Accuracy 70.833 (71.839)
# Epoch: [28][3400/17702]	Batch Time 0.446 (0.463)	Data Load Time 0.014 (0.005)	Loss 3.4719 (3.3877)	Top-5 Accuracy 69.399 (71.825)
# Epoch: [28][3500/17702]	Batch Time 0.391 (0.464)	Data Load Time 0.001 (0.005)	Loss 3.4274 (3.3876)	Top-5 Accuracy 70.604 (71.825)
# Epoch: [28][3600/17702]	Batch Time 0.396 (0.464)	Data Load Time 0.001 (0.005)	Loss 3.5669 (3.3882)	Top-5 Accuracy 71.816 (71.821)
# Epoch: [28][3700/17702]	Batch Time 0.425 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.5135 (3.3883)	Top-5 Accuracy 68.800 (71.819)
# Epoch: [28][3800/17702]	Batch Time 0.537 (0.463)	Data Load Time 0.012 (0.005)	Loss 3.5945 (3.3883)	Top-5 Accuracy 66.933 (71.819)
# Epoch: [28][3900/17702]	Batch Time 0.390 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.4777 (3.3884)	Top-5 Accuracy 68.362 (71.823)
# Epoch: [28][4000/17702]	Batch Time 0.403 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.4113 (3.3885)	Top-5 Accuracy 71.788 (71.823)
# Epoch: [28][4100/17702]	Batch Time 0.415 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.3089 (3.3886)	Top-5 Accuracy 73.046 (71.817)
# Epoch: [28][4200/17702]	Batch Time 0.426 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.2397 (3.3884)	Top-5 Accuracy 73.425 (71.822)
# Epoch: [28][4300/17702]	Batch Time 0.483 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.1942 (3.3886)	Top-5 Accuracy 75.487 (71.822)
# Epoch: [28][4400/17702]	Batch Time 0.425 (0.463)	Data Load Time 0.008 (0.005)	Loss 3.3186 (3.3894)	Top-5 Accuracy 71.023 (71.810)
# Epoch: [28][4500/17702]	Batch Time 0.439 (0.463)	Data Load Time 0.013 (0.005)	Loss 3.3361 (3.3895)	Top-5 Accuracy 70.765 (71.807)
# Epoch: [28][4600/17702]	Batch Time 0.541 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.7024 (3.3896)	Top-5 Accuracy 67.935 (71.803)
# Epoch: [28][4700/17702]	Batch Time 0.398 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.5484 (3.3895)	Top-5 Accuracy 68.182 (71.803)
# Epoch: [28][4800/17702]	Batch Time 0.517 (0.463)	Data Load Time 0.014 (0.005)	Loss 3.4081 (3.3901)	Top-5 Accuracy 71.389 (71.789)
# Epoch: [28][4900/17702]	Batch Time 0.461 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.4489 (3.3903)	Top-5 Accuracy 71.154 (71.795)
# Epoch: [28][5000/17702]	Batch Time 0.416 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.2749 (3.3906)	Top-5 Accuracy 74.095 (71.790)
# Epoch: [28][5100/17702]	Batch Time 0.413 (0.463)	Data Load Time 0.004 (0.005)	Loss 3.2508 (3.3907)	Top-5 Accuracy 75.207 (71.779)
# Epoch: [28][5200/17702]	Batch Time 0.538 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.2799 (3.3906)	Top-5 Accuracy 71.391 (71.784)
# Epoch: [28][5300/17702]	Batch Time 0.435 (0.463)	Data Load Time 0.014 (0.005)	Loss 3.5674 (3.3908)	Top-5 Accuracy 68.627 (71.784)
# Epoch: [28][5400/17702]	Batch Time 0.382 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.4340 (3.3912)	Top-5 Accuracy 70.029 (71.783)
# Epoch: [28][5500/17702]	Batch Time 0.451 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.2653 (3.3915)	Top-5 Accuracy 74.595 (71.783)
# Epoch: [28][5600/17702]	Batch Time 0.395 (0.463)	Data Load Time 0.001 (0.005)	Loss 3.3358 (3.3916)	Top-5 Accuracy 69.811 (71.786)
# Epoch: [28][5700/17702]	Batch Time 0.532 (0.464)	Data Load Time 0.001 (0.005)	Loss 3.3712 (3.3916)	Top-5 Accuracy 71.148 (71.788)
# Epoch: [28][5800/17702]	Batch Time 0.441 (0.464)	Data Load Time 0.001 (0.005)	Loss 3.4640 (3.3916)	Top-5 Accuracy 70.914 (71.788)
# Epoch: [28][5900/17702]	Batch Time 0.420 (0.464)	Data Load Time 0.011 (0.005)	Loss 3.1887 (3.3920)	Top-5 Accuracy 74.854 (71.788)
# Epoch: [28][6000/17702]	Batch Time 0.554 (0.464)	Data Load Time 0.014 (0.005)	Loss 3.5057 (3.3920)	Top-5 Accuracy 70.951 (71.782)
# Epoch: [28][6100/17702]	Batch Time 0.411 (0.464)	Data Load Time 0.014 (0.005)	Loss 3.3496 (3.3919)	Top-5 Accuracy 70.028 (71.785)
# Epoch: [28][6200/17702]	Batch Time 0.462 (0.464)	Data Load Time 0.013 (0.005)	Loss 3.2656 (3.3924)	Top-5 Accuracy 73.370 (71.777)
# Epoch: [28][6300/17702]	Batch Time 0.398 (0.464)	Data Load Time 0.001 (0.005)	Loss 3.3380 (3.3928)	Top-5 Accuracy 72.080 (71.770)
# Epoch: [28][6400/17702]	Batch Time 0.412 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.7172 (3.3933)	Top-5 Accuracy 68.232 (71.763)
# Epoch: [28][6500/17702]	Batch Time 0.438 (0.464)	Data Load Time 0.001 (0.005)	Loss 3.3531 (3.3937)	Top-5 Accuracy 71.467 (71.755)
# Epoch: [28][6600/17702]	Batch Time 0.454 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.5464 (3.3939)	Top-5 Accuracy 69.565 (71.753)
# Epoch: [28][6700/17702]	Batch Time 0.591 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.4613 (3.3944)	Top-5 Accuracy 72.368 (71.752)
# Epoch: [28][6800/17702]	Batch Time 0.412 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.3663 (3.3947)	Top-5 Accuracy 70.492 (71.744)
# Epoch: [28][6900/17702]	Batch Time 0.473 (0.465)	Data Load Time 0.023 (0.005)	Loss 3.6332 (3.3946)	Top-5 Accuracy 70.670 (71.745)
# Epoch: [28][7000/17702]	Batch Time 0.440 (0.465)	Data Load Time 0.014 (0.005)	Loss 3.3661 (3.3948)	Top-5 Accuracy 72.141 (71.746)
# Epoch: [28][7100/17702]	Batch Time 0.427 (0.465)	Data Load Time 0.014 (0.005)	Loss 3.5393 (3.3950)	Top-5 Accuracy 67.606 (71.744)
# Epoch: [28][7200/17702]	Batch Time 0.462 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.2592 (3.3952)	Top-5 Accuracy 70.959 (71.740)
# Epoch: [28][7300/17702]	Batch Time 0.594 (0.464)	Data Load Time 0.032 (0.005)	Loss 3.4813 (3.3953)	Top-5 Accuracy 68.883 (71.742)
# Epoch: [28][7400/17702]	Batch Time 0.530 (0.464)	Data Load Time 0.001 (0.005)	Loss 3.3316 (3.3952)	Top-5 Accuracy 71.848 (71.746)
# Epoch: [28][7500/17702]	Batch Time 0.438 (0.464)	Data Load Time 0.002 (0.005)	Loss 3.4114 (3.3957)	Top-5 Accuracy 70.085 (71.741)
# Epoch: [28][7600/17702]	Batch Time 0.470 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.5423 (3.3960)	Top-5 Accuracy 69.372 (71.736)
# Epoch: [28][7700/17702]	Batch Time 0.438 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.5052 (3.3963)	Top-5 Accuracy 69.516 (71.732)
# Epoch: [28][7800/17702]	Batch Time 0.413 (0.464)	Data Load Time 0.001 (0.005)	Loss 3.4800 (3.3966)	Top-5 Accuracy 72.394 (71.732)
# Epoch: [28][7900/17702]	Batch Time 0.497 (0.465)	Data Load Time 0.013 (0.005)	Loss 3.3817 (3.3968)	Top-5 Accuracy 74.105 (71.727)
# Epoch: [28][8000/17702]	Batch Time 0.422 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.2887 (3.3974)	Top-5 Accuracy 74.797 (71.719)
# Epoch: [28][8100/17702]	Batch Time 0.450 (0.465)	Data Load Time 0.026 (0.005)	Loss 3.5674 (3.3981)	Top-5 Accuracy 69.755 (71.714)
# Epoch: [28][8200/17702]	Batch Time 0.419 (0.465)	Data Load Time 0.014 (0.005)	Loss 3.2847 (3.3983)	Top-5 Accuracy 71.989 (71.710)
# Epoch: [28][8300/17702]	Batch Time 0.515 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.5281 (3.3985)	Top-5 Accuracy 69.191 (71.708)
# Epoch: [28][8400/17702]	Batch Time 0.390 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.3522 (3.3988)	Top-5 Accuracy 73.729 (71.705)
# Epoch: [28][8500/17702]	Batch Time 0.498 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.4637 (3.3991)	Top-5 Accuracy 72.237 (71.702)
# Epoch: [28][8600/17702]	Batch Time 0.441 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.4219 (3.3995)	Top-5 Accuracy 69.837 (71.698)
# Epoch: [28][8700/17702]	Batch Time 0.469 (0.465)	Data Load Time 0.014 (0.005)	Loss 3.2798 (3.3996)	Top-5 Accuracy 70.940 (71.696)
# Epoch: [28][8800/17702]	Batch Time 0.456 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.2753 (3.3997)	Top-5 Accuracy 74.785 (71.696)
# Epoch: [28][8900/17702]	Batch Time 0.535 (0.465)	Data Load Time 0.014 (0.005)	Loss 3.4003 (3.3999)	Top-5 Accuracy 73.514 (71.693)
# Epoch: [28][9000/17702]	Batch Time 0.417 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.5671 (3.4003)	Top-5 Accuracy 67.778 (71.689)
# Epoch: [28][9100/17702]	Batch Time 0.463 (0.466)	Data Load Time 0.014 (0.005)	Loss 3.2838 (3.4008)	Top-5 Accuracy 72.441 (71.682)
# Epoch: [28][9200/17702]	Batch Time 0.574 (0.466)	Data Load Time 0.014 (0.005)	Loss 3.6743 (3.4011)	Top-5 Accuracy 67.784 (71.679)
# Epoch: [28][9300/17702]	Batch Time 0.542 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3927 (3.4014)	Top-5 Accuracy 72.222 (71.676)
# Epoch: [28][9400/17702]	Batch Time 0.514 (0.466)	Data Load Time 0.012 (0.005)	Loss 3.2892 (3.4015)	Top-5 Accuracy 73.109 (71.673)
# Epoch: [28][9500/17702]	Batch Time 0.413 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.1726 (3.4015)	Top-5 Accuracy 73.563 (71.673)
# Epoch: [28][9600/17702]	Batch Time 0.466 (0.466)	Data Load Time 0.006 (0.005)	Loss 3.4679 (3.4017)	Top-5 Accuracy 71.148 (71.672)
# Epoch: [28][9700/17702]	Batch Time 0.479 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3220 (3.4020)	Top-5 Accuracy 73.569 (71.669)
# Epoch: [28][9800/17702]	Batch Time 0.442 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.2563 (3.4019)	Top-5 Accuracy 73.057 (71.670)
# Epoch: [28][9900/17702]	Batch Time 0.529 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.6932 (3.4019)	Top-5 Accuracy 67.082 (71.671)
# Epoch: [28][10000/17702]	Batch Time 0.426 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4329 (3.4020)	Top-5 Accuracy 71.762 (71.670)
# Epoch: [28][10100/17702]	Batch Time 0.410 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3246 (3.4020)	Top-5 Accuracy 74.000 (71.670)
# Epoch: [28][10200/17702]	Batch Time 0.425 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4892 (3.4024)	Top-5 Accuracy 72.087 (71.667)
# Epoch: [28][10300/17702]	Batch Time 0.469 (0.465)	Data Load Time 0.002 (0.005)	Loss 3.4826 (3.4025)	Top-5 Accuracy 69.973 (71.667)
# Epoch: [28][10400/17702]	Batch Time 0.440 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.2489 (3.4027)	Top-5 Accuracy 75.204 (71.663)
# Epoch: [28][10500/17702]	Batch Time 0.379 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3725 (3.4031)	Top-5 Accuracy 73.252 (71.656)
# Epoch: [28][10600/17702]	Batch Time 0.508 (0.465)	Data Load Time 0.014 (0.005)	Loss 3.3126 (3.4033)	Top-5 Accuracy 68.966 (71.654)
# Epoch: [28][10700/17702]	Batch Time 0.492 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.2470 (3.4036)	Top-5 Accuracy 74.935 (71.649)
# Epoch: [28][10800/17702]	Batch Time 0.394 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.3312 (3.4037)	Top-5 Accuracy 72.093 (71.647)
# Epoch: [28][10900/17702]	Batch Time 0.396 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.5024 (3.4041)	Top-5 Accuracy 68.733 (71.643)
# Epoch: [28][11000/17702]	Batch Time 0.541 (0.465)	Data Load Time 0.003 (0.005)	Loss 3.4669 (3.4041)	Top-5 Accuracy 72.176 (71.646)
# Epoch: [28][11100/17702]	Batch Time 0.410 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.3855 (3.4041)	Top-5 Accuracy 73.740 (71.649)
# Epoch: [28][11200/17702]	Batch Time 0.452 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.3698 (3.4044)	Top-5 Accuracy 71.839 (71.646)
# Epoch: [28][11300/17702]	Batch Time 0.519 (0.465)	Data Load Time 0.012 (0.005)	Loss 3.2033 (3.4048)	Top-5 Accuracy 70.976 (71.642)
# Epoch: [28][11400/17702]	Batch Time 0.418 (0.465)	Data Load Time 0.008 (0.005)	Loss 3.3944 (3.4052)	Top-5 Accuracy 70.492 (71.635)
# Epoch: [28][11500/17702]	Batch Time 0.413 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.5029 (3.4055)	Top-5 Accuracy 71.629 (71.631)
# Epoch: [28][11600/17702]	Batch Time 0.634 (0.465)	Data Load Time 0.014 (0.005)	Loss 3.4889 (3.4057)	Top-5 Accuracy 69.409 (71.629)
# Epoch: [28][11700/17702]	Batch Time 0.501 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.4704 (3.4058)	Top-5 Accuracy 69.388 (71.628)
# Epoch: [28][11800/17702]	Batch Time 0.476 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.4128 (3.4062)	Top-5 Accuracy 70.699 (71.625)
# Epoch: [28][11900/17702]	Batch Time 0.428 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.2850 (3.4062)	Top-5 Accuracy 73.950 (71.628)
# Epoch: [28][12000/17702]	Batch Time 0.430 (0.465)	Data Load Time 0.001 (0.005)	Loss 3.4945 (3.4064)	Top-5 Accuracy 71.892 (71.626)
# Epoch: [28][12100/17702]	Batch Time 0.496 (0.465)	Data Load Time 0.014 (0.005)	Loss 3.5820 (3.4068)	Top-5 Accuracy 70.083 (71.621)
# Epoch: [28][12200/17702]	Batch Time 0.570 (0.465)	Data Load Time 0.013 (0.005)	Loss 3.3874 (3.4069)	Top-5 Accuracy 73.297 (71.619)
# Epoch: [28][12300/17702]	Batch Time 0.506 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4235 (3.4072)	Top-5 Accuracy 70.556 (71.615)
# Epoch: [28][12400/17702]	Batch Time 0.519 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3670 (3.4074)	Top-5 Accuracy 72.774 (71.613)
# Epoch: [28][12500/17702]	Batch Time 0.526 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3118 (3.4075)	Top-5 Accuracy 73.925 (71.611)
# Epoch: [28][12600/17702]	Batch Time 0.518 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.6331 (3.4077)	Top-5 Accuracy 70.621 (71.609)
# Epoch: [28][12700/17702]	Batch Time 0.477 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4801 (3.4080)	Top-5 Accuracy 71.875 (71.605)
# Epoch: [28][12800/17702]	Batch Time 0.502 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3503 (3.4080)	Top-5 Accuracy 71.979 (71.605)
# Epoch: [28][12900/17702]	Batch Time 0.424 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3928 (3.4081)	Top-5 Accuracy 70.604 (71.603)
# Epoch: [28][13000/17702]	Batch Time 0.609 (0.466)	Data Load Time 0.013 (0.005)	Loss 3.8377 (3.4083)	Top-5 Accuracy 64.894 (71.602)
# Epoch: [28][13100/17702]	Batch Time 0.567 (0.466)	Data Load Time 0.018 (0.005)	Loss 3.5959 (3.4085)	Top-5 Accuracy 68.564 (71.599)
# Epoch: [28][13200/17702]	Batch Time 0.467 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3311 (3.4087)	Top-5 Accuracy 70.115 (71.595)
# Epoch: [28][13300/17702]	Batch Time 0.432 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.8168 (3.4089)	Top-5 Accuracy 61.408 (71.593)
# Epoch: [28][13400/17702]	Batch Time 0.485 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4213 (3.4089)	Top-5 Accuracy 71.892 (71.592)
# Epoch: [28][13500/17702]	Batch Time 0.454 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4106 (3.4091)	Top-5 Accuracy 69.706 (71.590)
# Epoch: [28][13600/17702]	Batch Time 0.598 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.6972 (3.4094)	Top-5 Accuracy 67.949 (71.584)
# Epoch: [28][13700/17702]	Batch Time 0.482 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.5828 (3.4094)	Top-5 Accuracy 70.026 (71.584)
# Epoch: [28][13800/17702]	Batch Time 0.527 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3232 (3.4094)	Top-5 Accuracy 74.026 (71.585)
# Epoch: [28][13900/17702]	Batch Time 0.531 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4022 (3.4096)	Top-5 Accuracy 72.021 (71.584)
# Epoch: [28][14000/17702]	Batch Time 0.448 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3842 (3.4097)	Top-5 Accuracy 72.849 (71.583)
# Epoch: [28][14100/17702]	Batch Time 0.506 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.6772 (3.4096)	Top-5 Accuracy 69.452 (71.584)
# Epoch: [28][14200/17702]	Batch Time 0.394 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.1899 (3.4097)	Top-5 Accuracy 72.434 (71.583)
# Epoch: [28][14300/17702]	Batch Time 0.453 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.6182 (3.4098)	Top-5 Accuracy 67.218 (71.582)
# Epoch: [28][14400/17702]	Batch Time 0.560 (0.466)	Data Load Time 0.014 (0.005)	Loss 3.2973 (3.4099)	Top-5 Accuracy 73.077 (71.580)
# Epoch: [28][14500/17702]	Batch Time 0.489 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.5212 (3.4100)	Top-5 Accuracy 70.777 (71.578)
# Epoch: [28][14600/17702]	Batch Time 0.504 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.1912 (3.4102)	Top-5 Accuracy 75.882 (71.576)
# Epoch: [28][14700/17702]	Batch Time 0.525 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4180 (3.4103)	Top-5 Accuracy 72.123 (71.576)
# Epoch: [28][14800/17702]	Batch Time 0.392 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3115 (3.4103)	Top-5 Accuracy 74.128 (71.575)
# Epoch: [28][14900/17702]	Batch Time 0.553 (0.466)	Data Load Time 0.024 (0.005)	Loss 3.8705 (3.4104)	Top-5 Accuracy 64.917 (71.574)
# Epoch: [28][15000/17702]	Batch Time 0.487 (0.466)	Data Load Time 0.014 (0.005)	Loss 3.5737 (3.4106)	Top-5 Accuracy 71.622 (71.571)
# Epoch: [28][15100/17702]	Batch Time 0.449 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.6967 (3.4107)	Top-5 Accuracy 66.859 (71.571)
# Epoch: [28][15200/17702]	Batch Time 0.574 (0.466)	Data Load Time 0.014 (0.005)	Loss 3.3321 (3.4110)	Top-5 Accuracy 71.625 (71.569)
# Epoch: [28][15300/17702]	Batch Time 0.438 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3348 (3.4111)	Top-5 Accuracy 74.799 (71.569)
# Epoch: [28][15400/17702]	Batch Time 0.511 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4086 (3.4113)	Top-5 Accuracy 71.309 (71.567)
# Epoch: [28][15500/17702]	Batch Time 0.412 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.6297 (3.4115)	Top-5 Accuracy 69.377 (71.565)
# Epoch: [28][15600/17702]	Batch Time 0.410 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.1815 (3.4116)	Top-5 Accuracy 76.437 (71.564)
# Epoch: [28][15700/17702]	Batch Time 0.422 (0.466)	Data Load Time 0.020 (0.005)	Loss 3.0164 (3.4117)	Top-5 Accuracy 76.536 (71.565)
# Epoch: [28][15800/17702]	Batch Time 0.401 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4787 (3.4119)	Top-5 Accuracy 70.950 (71.562)
# Epoch: [28][15900/17702]	Batch Time 0.443 (0.466)	Data Load Time 0.013 (0.005)	Loss 3.5407 (3.4122)	Top-5 Accuracy 68.091 (71.560)
# Epoch: [28][16000/17702]	Batch Time 0.488 (0.466)	Data Load Time 0.014 (0.005)	Loss 3.5927 (3.4124)	Top-5 Accuracy 69.797 (71.558)
# Epoch: [28][16100/17702]	Batch Time 0.430 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.5727 (3.4127)	Top-5 Accuracy 69.492 (71.555)
# Epoch: [28][16200/17702]	Batch Time 0.513 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.5634 (3.4127)	Top-5 Accuracy 67.700 (71.554)
# Epoch: [28][16300/17702]	Batch Time 0.494 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.1466 (3.4129)	Top-5 Accuracy 74.745 (71.552)
# Epoch: [28][16400/17702]	Batch Time 0.427 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4113 (3.4130)	Top-5 Accuracy 71.169 (71.551)
# Epoch: [28][16500/17702]	Batch Time 0.464 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3201 (3.4132)	Top-5 Accuracy 69.705 (71.547)
# Epoch: [28][16600/17702]	Batch Time 0.541 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.5612 (3.4133)	Top-5 Accuracy 68.193 (71.546)
# Epoch: [28][16700/17702]	Batch Time 0.487 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.1258 (3.4134)	Top-5 Accuracy 75.209 (71.546)
# Epoch: [28][16800/17702]	Batch Time 0.489 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3549 (3.4135)	Top-5 Accuracy 73.684 (71.545)
# Epoch: [28][16900/17702]	Batch Time 0.520 (0.466)	Data Load Time 0.014 (0.005)	Loss 3.3220 (3.4136)	Top-5 Accuracy 74.795 (71.544)
# Epoch: [28][17000/17702]	Batch Time 0.425 (0.466)	Data Load Time 0.014 (0.005)	Loss 3.5916 (3.4136)	Top-5 Accuracy 70.000 (71.543)
# Epoch: [28][17100/17702]	Batch Time 0.440 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3910 (3.4138)	Top-5 Accuracy 72.191 (71.541)
# Epoch: [28][17200/17702]	Batch Time 0.570 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.5184 (3.4138)	Top-5 Accuracy 71.842 (71.540)
# Epoch: [28][17300/17702]	Batch Time 0.506 (0.466)	Data Load Time 0.013 (0.005)	Loss 3.3403 (3.4140)	Top-5 Accuracy 72.944 (71.536)
# Epoch: [28][17400/17702]	Batch Time 0.477 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.2817 (3.4141)	Top-5 Accuracy 73.088 (71.535)
# Epoch: [28][17500/17702]	Batch Time 0.417 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4858 (3.4143)	Top-5 Accuracy 69.972 (71.533)
# Epoch: [28][17600/17702]	Batch Time 0.500 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.4571 (3.4145)	Top-5 Accuracy 69.705 (71.531)
# Epoch: [28][17700/17702]	Batch Time 0.461 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.5172 (3.4146)	Top-5 Accuracy 69.169 (71.529)
# Validation: [0/782]	Batch Time 0.978 (0.978)	Loss 3.7993 (3.7993)	Top-5 Accuracy 66.393 (66.393)
# Validation: [100/782]	Batch Time 0.339 (0.328)	Loss 3.4487 (3.7017)	Top-5 Accuracy 72.222 (68.916)
# Validation: [200/782]	Batch Time 0.300 (0.324)	Loss 3.6484 (3.6959)	Top-5 Accuracy 70.732 (68.761)
# Validation: [300/782]	Batch Time 0.290 (0.324)	Loss 3.7577 (3.7032)	Top-5 Accuracy 69.914 (68.751)
# Validation: [400/782]	Batch Time 0.323 (0.324)	Loss 3.7372 (3.7063)	Top-5 Accuracy 69.624 (68.754)
# Validation: [500/782]	Batch Time 0.320 (0.324)	Loss 3.6957 (3.7090)	Top-5 Accuracy 66.954 (68.763)
# Validation: [600/782]	Batch Time 0.291 (0.324)	Loss 3.6255 (3.7095)	Top-5 Accuracy 67.422 (68.785)
# Validation: [700/782]	Batch Time 0.332 (0.324)	Loss 3.8484 (3.7097)	Top-5 Accuracy 67.778 (68.753)
#
#  * LOSS - 3.708, TOP-5 ACCURACY - 68.774, BLEU-4 - 0.14630808121012048
#
#
# Epochs since last improvement: 5
#
# Epoch: [29][0/17702]	Batch Time 1.359 (1.359)	Data Load Time 0.910 (0.910)	Loss 3.2572 (3.2572)	Top-5 Accuracy 72.944 (72.944)
# Epoch: [29][100/17702]	Batch Time 0.609 (0.473)	Data Load Time 0.001 (0.013)	Loss 3.3434 (3.3442)	Top-5 Accuracy 72.093 (72.006)
# Epoch: [29][200/17702]	Batch Time 0.504 (0.469)	Data Load Time 0.013 (0.009)	Loss 3.3334 (3.3425)	Top-5 Accuracy 72.944 (72.108)
# Epoch: [29][300/17702]	Batch Time 0.517 (0.472)	Data Load Time 0.001 (0.008)	Loss 3.5377 (3.3562)	Top-5 Accuracy 71.233 (72.062)
# Epoch: [29][400/17702]	Batch Time 0.419 (0.472)	Data Load Time 0.001 (0.007)	Loss 3.3137 (3.3521)	Top-5 Accuracy 74.044 (72.105)
# Epoch: [29][500/17702]	Batch Time 0.466 (0.470)	Data Load Time 0.022 (0.007)	Loss 3.3475 (3.3554)	Top-5 Accuracy 71.925 (72.142)
# Epoch: [29][600/17702]	Batch Time 0.699 (0.469)	Data Load Time 0.014 (0.006)	Loss 3.4817 (3.3533)	Top-5 Accuracy 73.250 (72.209)
# Epoch: [29][700/17702]	Batch Time 0.441 (0.470)	Data Load Time 0.014 (0.006)	Loss 3.2073 (3.3600)	Top-5 Accuracy 72.581 (72.114)
# Epoch: [29][800/17702]	Batch Time 0.520 (0.470)	Data Load Time 0.015 (0.006)	Loss 3.3677 (3.3596)	Top-5 Accuracy 71.676 (72.149)
# Epoch: [29][900/17702]	Batch Time 0.407 (0.469)	Data Load Time 0.001 (0.006)	Loss 3.3352 (3.3601)	Top-5 Accuracy 70.933 (72.116)
# Epoch: [29][1000/17702]	Batch Time 0.488 (0.470)	Data Load Time 0.001 (0.006)	Loss 3.3963 (3.3608)	Top-5 Accuracy 73.280 (72.111)
# Epoch: [29][1100/17702]	Batch Time 0.429 (0.468)	Data Load Time 0.025 (0.005)	Loss 3.2554 (3.3622)	Top-5 Accuracy 74.521 (72.085)
# Epoch: [29][1200/17702]	Batch Time 0.491 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3243 (3.3630)	Top-5 Accuracy 74.432 (72.071)
# Epoch: [29][1300/17702]	Batch Time 0.442 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.3793 (3.3635)	Top-5 Accuracy 74.247 (72.066)
# Epoch: [29][1400/17702]	Batch Time 0.428 (0.469)	Data Load Time 0.014 (0.005)	Loss 3.6163 (3.3649)	Top-5 Accuracy 70.725 (72.056)
# Epoch: [29][1500/17702]	Batch Time 0.479 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.3588 (3.3663)	Top-5 Accuracy 70.950 (72.049)
# Epoch: [29][1600/17702]	Batch Time 0.557 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.2065 (3.3675)	Top-5 Accuracy 75.936 (72.038)
# Epoch: [29][1700/17702]	Batch Time 0.467 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4909 (3.3683)	Top-5 Accuracy 67.688 (72.021)
# Epoch: [29][1800/17702]	Batch Time 0.441 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2014 (3.3691)	Top-5 Accuracy 75.424 (72.026)
# Epoch: [29][1900/17702]	Batch Time 0.422 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3082 (3.3696)	Top-5 Accuracy 71.739 (72.028)
# Epoch: [29][2000/17702]	Batch Time 0.451 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.1078 (3.3688)	Top-5 Accuracy 77.119 (72.038)
# Epoch: [29][2100/17702]	Batch Time 0.426 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3074 (3.3693)	Top-5 Accuracy 73.262 (72.032)
# Epoch: [29][2200/17702]	Batch Time 0.406 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.3533 (3.3694)	Top-5 Accuracy 72.554 (72.024)
# Epoch: [29][2300/17702]	Batch Time 0.473 (0.467)	Data Load Time 0.013 (0.005)	Loss 3.2039 (3.3704)	Top-5 Accuracy 73.178 (72.005)
# Epoch: [29][2400/17702]	Batch Time 0.438 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.6257 (3.3710)	Top-5 Accuracy 66.301 (71.983)
# Epoch: [29][2500/17702]	Batch Time 0.458 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.5297 (3.3717)	Top-5 Accuracy 69.890 (71.976)
# Epoch: [29][2600/17702]	Batch Time 0.411 (0.467)	Data Load Time 0.014 (0.005)	Loss 3.2930 (3.3716)	Top-5 Accuracy 74.294 (71.974)
# Epoch: [29][2700/17702]	Batch Time 0.432 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.6874 (3.3718)	Top-5 Accuracy 71.186 (71.964)
# Epoch: [29][2800/17702]	Batch Time 0.475 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.4914 (3.3723)	Top-5 Accuracy 70.889 (71.967)
# Epoch: [29][2900/17702]	Batch Time 0.449 (0.467)	Data Load Time 0.010 (0.005)	Loss 3.2836 (3.3719)	Top-5 Accuracy 73.387 (71.966)
# Epoch: [29][3000/17702]	Batch Time 0.454 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.1728 (3.3714)	Top-5 Accuracy 74.866 (71.971)
# Epoch: [29][3100/17702]	Batch Time 0.477 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.4676 (3.3721)	Top-5 Accuracy 72.043 (71.959)
# Epoch: [29][3200/17702]	Batch Time 0.545 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.3499 (3.3724)	Top-5 Accuracy 73.867 (71.960)
# Epoch: [29][3300/17702]	Batch Time 0.452 (0.467)	Data Load Time 0.014 (0.005)	Loss 3.2950 (3.3731)	Top-5 Accuracy 72.423 (71.950)
# Epoch: [29][3400/17702]	Batch Time 0.458 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.3289 (3.3735)	Top-5 Accuracy 72.340 (71.941)
# Epoch: [29][3500/17702]	Batch Time 0.445 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.3906 (3.3748)	Top-5 Accuracy 73.025 (71.928)
# Epoch: [29][3600/17702]	Batch Time 0.423 (0.467)	Data Load Time 0.023 (0.005)	Loss 3.3239 (3.3748)	Top-5 Accuracy 74.247 (71.926)
# Epoch: [29][3700/17702]	Batch Time 0.512 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.5306 (3.3746)	Top-5 Accuracy 70.968 (71.925)
# Epoch: [29][3800/17702]	Batch Time 0.555 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3784 (3.3752)	Top-5 Accuracy 70.370 (71.918)
# Epoch: [29][3900/17702]	Batch Time 0.414 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3524 (3.3756)	Top-5 Accuracy 71.468 (71.913)
# Epoch: [29][4000/17702]	Batch Time 0.401 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.2038 (3.3757)	Top-5 Accuracy 73.333 (71.918)
# Epoch: [29][4100/17702]	Batch Time 0.478 (0.466)	Data Load Time 0.001 (0.005)	Loss 3.3897 (3.3761)	Top-5 Accuracy 72.776 (71.913)
# Epoch: [29][4200/17702]	Batch Time 0.449 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.3011 (3.3757)	Top-5 Accuracy 74.863 (71.921)
# Epoch: [29][4300/17702]	Batch Time 0.443 (0.467)	Data Load Time 0.012 (0.005)	Loss 3.4350 (3.3767)	Top-5 Accuracy 69.529 (71.906)
# Epoch: [29][4400/17702]	Batch Time 0.419 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.4399 (3.3768)	Top-5 Accuracy 70.000 (71.904)
# Epoch: [29][4500/17702]	Batch Time 0.544 (0.467)	Data Load Time 0.014 (0.005)	Loss 3.5163 (3.3768)	Top-5 Accuracy 69.430 (71.904)
# Epoch: [29][4600/17702]	Batch Time 0.449 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.2881 (3.3768)	Top-5 Accuracy 73.684 (71.902)
# Epoch: [29][4700/17702]	Batch Time 0.473 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.1200 (3.3770)	Top-5 Accuracy 72.654 (71.904)
# Epoch: [29][4800/17702]	Batch Time 0.410 (0.467)	Data Load Time 0.005 (0.005)	Loss 3.0442 (3.3772)	Top-5 Accuracy 76.301 (71.900)
# Epoch: [29][4900/17702]	Batch Time 0.437 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.2242 (3.3772)	Top-5 Accuracy 71.512 (71.901)
# Epoch: [29][5000/17702]	Batch Time 0.439 (0.467)	Data Load Time 0.017 (0.005)	Loss 3.4003 (3.3777)	Top-5 Accuracy 70.718 (71.892)
# Epoch: [29][5100/17702]	Batch Time 0.514 (0.467)	Data Load Time 0.029 (0.005)	Loss 3.3234 (3.3777)	Top-5 Accuracy 73.552 (71.892)
# Epoch: [29][5200/17702]	Batch Time 0.433 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.4355 (3.3780)	Top-5 Accuracy 69.542 (71.885)
# Epoch: [29][5300/17702]	Batch Time 0.458 (0.467)	Data Load Time 0.014 (0.005)	Loss 3.3477 (3.3782)	Top-5 Accuracy 70.360 (71.887)
# Epoch: [29][5400/17702]	Batch Time 0.411 (0.467)	Data Load Time 0.014 (0.005)	Loss 3.3792 (3.3781)	Top-5 Accuracy 71.164 (71.892)
# Epoch: [29][5500/17702]	Batch Time 0.462 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.3173 (3.3784)	Top-5 Accuracy 71.038 (71.887)
# Epoch: [29][5600/17702]	Batch Time 0.457 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.5066 (3.3790)	Top-5 Accuracy 70.833 (71.884)
# Epoch: [29][5700/17702]	Batch Time 0.408 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.5976 (3.3794)	Top-5 Accuracy 69.189 (71.876)
# Epoch: [29][5800/17702]	Batch Time 0.438 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.3010 (3.3799)	Top-5 Accuracy 72.500 (71.869)
# Epoch: [29][5900/17702]	Batch Time 0.418 (0.468)	Data Load Time 0.012 (0.005)	Loss 3.1788 (3.3806)	Top-5 Accuracy 75.881 (71.858)
# Epoch: [29][6000/17702]	Batch Time 0.427 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3216 (3.3807)	Top-5 Accuracy 71.388 (71.857)
# Epoch: [29][6100/17702]	Batch Time 0.466 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3481 (3.3808)	Top-5 Accuracy 73.529 (71.856)
# Epoch: [29][6200/17702]	Batch Time 0.438 (0.468)	Data Load Time 0.018 (0.005)	Loss 3.4454 (3.3814)	Top-5 Accuracy 71.989 (71.848)
# Epoch: [29][6300/17702]	Batch Time 0.528 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4579 (3.3816)	Top-5 Accuracy 72.021 (71.845)
# Epoch: [29][6400/17702]	Batch Time 0.581 (0.468)	Data Load Time 0.014 (0.005)	Loss 3.3396 (3.3815)	Top-5 Accuracy 74.300 (71.851)
# Epoch: [29][6500/17702]	Batch Time 0.535 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.5608 (3.3815)	Top-5 Accuracy 68.533 (71.853)
# Epoch: [29][6600/17702]	Batch Time 0.479 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.6534 (3.3819)	Top-5 Accuracy 67.602 (71.845)
# Epoch: [29][6700/17702]	Batch Time 0.512 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3003 (3.3823)	Top-5 Accuracy 74.615 (71.842)
# Epoch: [29][6800/17702]	Batch Time 0.539 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.6260 (3.3828)	Top-5 Accuracy 69.437 (71.833)
# Epoch: [29][6900/17702]	Batch Time 0.400 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3572 (3.3830)	Top-5 Accuracy 72.500 (71.833)
# Epoch: [29][7000/17702]	Batch Time 0.438 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.5519 (3.3831)	Top-5 Accuracy 70.170 (71.831)
# Epoch: [29][7100/17702]	Batch Time 0.546 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.3567 (3.3833)	Top-5 Accuracy 72.358 (71.830)
# Epoch: [29][7200/17702]	Batch Time 0.419 (0.467)	Data Load Time 0.008 (0.005)	Loss 3.4106 (3.3837)	Top-5 Accuracy 73.425 (71.824)
# Epoch: [29][7300/17702]	Batch Time 0.441 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.5039 (3.3840)	Top-5 Accuracy 71.698 (71.823)
# Epoch: [29][7400/17702]	Batch Time 0.515 (0.468)	Data Load Time 0.013 (0.005)	Loss 3.5752 (3.3842)	Top-5 Accuracy 69.663 (71.821)
# Epoch: [29][7500/17702]	Batch Time 0.420 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3751 (3.3845)	Top-5 Accuracy 73.407 (71.820)
# Epoch: [29][7600/17702]	Batch Time 0.578 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2489 (3.3845)	Top-5 Accuracy 74.627 (71.821)
# Epoch: [29][7700/17702]	Batch Time 0.480 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.1444 (3.3848)	Top-5 Accuracy 74.737 (71.818)
# Epoch: [29][7800/17702]	Batch Time 0.416 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3674 (3.3851)	Top-5 Accuracy 68.135 (71.815)
# Epoch: [29][7900/17702]	Batch Time 0.471 (0.468)	Data Load Time 0.013 (0.005)	Loss 3.3479 (3.3851)	Top-5 Accuracy 74.085 (71.816)
# Epoch: [29][8000/17702]	Batch Time 0.528 (0.468)	Data Load Time 0.014 (0.005)	Loss 3.4081 (3.3854)	Top-5 Accuracy 71.316 (71.810)
# Epoch: [29][8100/17702]	Batch Time 0.413 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2970 (3.3855)	Top-5 Accuracy 72.751 (71.807)
# Epoch: [29][8200/17702]	Batch Time 0.421 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2969 (3.3855)	Top-5 Accuracy 73.151 (71.807)
# Epoch: [29][8300/17702]	Batch Time 0.453 (0.468)	Data Load Time 0.010 (0.005)	Loss 3.7617 (3.3858)	Top-5 Accuracy 67.978 (71.805)
# Epoch: [29][8400/17702]	Batch Time 0.444 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4310 (3.3856)	Top-5 Accuracy 70.083 (71.807)
# Epoch: [29][8500/17702]	Batch Time 0.436 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.5218 (3.3861)	Top-5 Accuracy 68.800 (71.797)
# Epoch: [29][8600/17702]	Batch Time 0.494 (0.467)	Data Load Time 0.026 (0.005)	Loss 3.5032 (3.3865)	Top-5 Accuracy 70.248 (71.791)
# Epoch: [29][8700/17702]	Batch Time 0.397 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.4264 (3.3866)	Top-5 Accuracy 73.713 (71.792)
# Epoch: [29][8800/17702]	Batch Time 0.484 (0.467)	Data Load Time 0.014 (0.005)	Loss 3.3147 (3.3870)	Top-5 Accuracy 75.000 (71.790)
# Epoch: [29][8900/17702]	Batch Time 0.470 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.1129 (3.3872)	Top-5 Accuracy 72.581 (71.789)
# Epoch: [29][9000/17702]	Batch Time 0.453 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3003 (3.3875)	Top-5 Accuracy 70.027 (71.786)
# Epoch: [29][9100/17702]	Batch Time 0.441 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.2572 (3.3878)	Top-5 Accuracy 74.531 (71.782)
# Epoch: [29][9200/17702]	Batch Time 0.528 (0.468)	Data Load Time 0.015 (0.005)	Loss 3.3393 (3.3877)	Top-5 Accuracy 72.951 (71.784)
# Epoch: [29][9300/17702]	Batch Time 0.473 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4513 (3.3884)	Top-5 Accuracy 73.757 (71.775)
# Epoch: [29][9400/17702]	Batch Time 0.411 (0.467)	Data Load Time 0.001 (0.005)	Loss 3.4934 (3.3885)	Top-5 Accuracy 68.067 (71.774)
# Epoch: [29][9500/17702]	Batch Time 0.479 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.1629 (3.3889)	Top-5 Accuracy 74.359 (71.769)
# Epoch: [29][9600/17702]	Batch Time 0.455 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3313 (3.3888)	Top-5 Accuracy 71.507 (71.770)
# Epoch: [29][9700/17702]	Batch Time 0.415 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.5934 (3.3890)	Top-5 Accuracy 67.590 (71.767)
# Epoch: [29][9800/17702]	Batch Time 0.389 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.0986 (3.3894)	Top-5 Accuracy 76.437 (71.762)
# Epoch: [29][9900/17702]	Batch Time 0.540 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3647 (3.3898)	Top-5 Accuracy 73.118 (71.756)
# Epoch: [29][10000/17702]	Batch Time 0.505 (0.468)	Data Load Time 0.014 (0.005)	Loss 3.4988 (3.3901)	Top-5 Accuracy 68.120 (71.752)
# Epoch: [29][10100/17702]	Batch Time 0.481 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3797 (3.3904)	Top-5 Accuracy 73.925 (71.749)
# Epoch: [29][10200/17702]	Batch Time 0.400 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2484 (3.3904)	Top-5 Accuracy 72.802 (71.748)
# Epoch: [29][10300/17702]	Batch Time 0.421 (0.468)	Data Load Time 0.014 (0.005)	Loss 3.4876 (3.3907)	Top-5 Accuracy 70.225 (71.746)
# Epoch: [29][10400/17702]	Batch Time 0.452 (0.468)	Data Load Time 0.014 (0.005)	Loss 3.4958 (3.3910)	Top-5 Accuracy 70.950 (71.743)
# Epoch: [29][10500/17702]	Batch Time 0.438 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2908 (3.3910)	Top-5 Accuracy 74.462 (71.744)
# Epoch: [29][10600/17702]	Batch Time 0.413 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.1962 (3.3912)	Top-5 Accuracy 73.512 (71.743)
# Epoch: [29][10700/17702]	Batch Time 0.416 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.5279 (3.3913)	Top-5 Accuracy 71.469 (71.743)
# Epoch: [29][10800/17702]	Batch Time 0.402 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2541 (3.3915)	Top-5 Accuracy 73.961 (71.742)
# Epoch: [29][10900/17702]	Batch Time 0.418 (0.468)	Data Load Time 0.014 (0.005)	Loss 3.2246 (3.3917)	Top-5 Accuracy 76.111 (71.740)
# Epoch: [29][11000/17702]	Batch Time 0.442 (0.468)	Data Load Time 0.002 (0.005)	Loss 3.6600 (3.3922)	Top-5 Accuracy 69.553 (71.736)
# Epoch: [29][11100/17702]	Batch Time 0.592 (0.468)	Data Load Time 0.014 (0.005)	Loss 3.4564 (3.3925)	Top-5 Accuracy 70.112 (71.732)
# Epoch: [29][11200/17702]	Batch Time 0.452 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.5775 (3.3927)	Top-5 Accuracy 72.533 (71.734)
# Epoch: [29][11300/17702]	Batch Time 0.487 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3598 (3.3927)	Top-5 Accuracy 74.859 (71.734)
# Epoch: [29][11400/17702]	Batch Time 0.452 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.5931 (3.3931)	Top-5 Accuracy 71.907 (71.731)
# Epoch: [29][11500/17702]	Batch Time 0.546 (0.468)	Data Load Time 0.014 (0.005)	Loss 3.4126 (3.3932)	Top-5 Accuracy 71.703 (71.731)
# Epoch: [29][11600/17702]	Batch Time 0.389 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3234 (3.3934)	Top-5 Accuracy 73.315 (71.729)
# Epoch: [29][11700/17702]	Batch Time 0.436 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.5235 (3.3938)	Top-5 Accuracy 68.611 (71.727)
# Epoch: [29][11800/17702]	Batch Time 0.495 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3909 (3.3939)	Top-5 Accuracy 72.312 (71.725)
# Epoch: [29][11900/17702]	Batch Time 0.738 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4759 (3.3941)	Top-5 Accuracy 71.354 (71.723)
# Epoch: [29][12000/17702]	Batch Time 0.417 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.7349 (3.3942)	Top-5 Accuracy 66.477 (71.724)
# Epoch: [29][12100/17702]	Batch Time 0.402 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.5229 (3.3943)	Top-5 Accuracy 72.222 (71.722)
# Epoch: [29][12200/17702]	Batch Time 0.410 (0.468)	Data Load Time 0.014 (0.005)	Loss 3.2618 (3.3945)	Top-5 Accuracy 69.944 (71.720)
# Epoch: [29][12300/17702]	Batch Time 0.613 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2534 (3.3947)	Top-5 Accuracy 72.423 (71.719)
# Epoch: [29][12400/17702]	Batch Time 0.719 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.6993 (3.3950)	Top-5 Accuracy 68.286 (71.717)
# Epoch: [29][12700/17702]	Batch Time 0.486 (0.468)	Data Load Time 0.012 (0.005)	Loss 3.2609 (3.3958)	Top-5 Accuracy 75.070 (71.709)
# Epoch: [29][12800/17702]	Batch Time 0.474 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.6152 (3.3959)	Top-5 Accuracy 69.689 (71.705)
# Epoch: [29][12900/17702]	Batch Time 0.436 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4566 (3.3962)	Top-5 Accuracy 68.408 (71.703)
# Epoch: [29][13000/17702]	Batch Time 0.435 (0.468)	Data Load Time 0.026 (0.005)	Loss 3.5633 (3.3963)	Top-5 Accuracy 71.237 (71.704)
# Epoch: [29][13100/17702]	Batch Time 0.439 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4437 (3.3965)	Top-5 Accuracy 71.088 (71.701)
# Epoch: [29][13200/17702]	Batch Time 0.510 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4378 (3.3964)	Top-5 Accuracy 71.212 (71.705)
# Epoch: [29][13300/17702]	Batch Time 0.443 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4473 (3.3967)	Top-5 Accuracy 68.378 (71.702)
# Epoch: [29][13400/17702]	Batch Time 0.450 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.6869 (3.3970)	Top-5 Accuracy 68.824 (71.700)
# Epoch: [29][13500/17702]	Batch Time 0.484 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.1979 (3.3970)	Top-5 Accuracy 75.130 (71.702)
# Epoch: [29][13600/17702]	Batch Time 0.415 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4920 (3.3972)	Top-5 Accuracy 70.868 (71.700)
# Epoch: [29][13700/17702]	Batch Time 0.560 (0.468)	Data Load Time 0.014 (0.005)	Loss 3.6799 (3.3973)	Top-5 Accuracy 71.348 (71.700)
# Epoch: [29][13800/17702]	Batch Time 0.406 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3975 (3.3974)	Top-5 Accuracy 72.394 (71.699)
# Epoch: [29][13900/17702]	Batch Time 0.489 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.7040 (3.3975)	Top-5 Accuracy 67.095 (71.696)
# Epoch: [29][14000/17702]	Batch Time 0.489 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.5084 (3.3976)	Top-5 Accuracy 68.338 (71.695)
# Epoch: [29][14100/17702]	Batch Time 0.425 (0.468)	Data Load Time 0.013 (0.005)	Loss 3.4690 (3.3978)	Top-5 Accuracy 73.066 (71.692)
# Epoch: [29][14200/17702]	Batch Time 0.485 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4868 (3.3979)	Top-5 Accuracy 71.842 (71.691)
# Epoch: [29][14300/17702]	Batch Time 0.478 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.3704 (3.3983)	Top-5 Accuracy 72.632 (71.688)
# Epoch: [29][14400/17702]	Batch Time 0.408 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2731 (3.3986)	Top-5 Accuracy 74.294 (71.685)
# Epoch: [29][14500/17702]	Batch Time 0.410 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4751 (3.3988)	Top-5 Accuracy 71.831 (71.683)
# Epoch: [29][14600/17702]	Batch Time 0.516 (0.468)	Data Load Time 0.014 (0.005)	Loss 3.4736 (3.3990)	Top-5 Accuracy 70.509 (71.681)
# Epoch: [29][14700/17702]	Batch Time 0.452 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2810 (3.3990)	Top-5 Accuracy 73.761 (71.682)
# Epoch: [29][14800/17702]	Batch Time 0.457 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.5319 (3.3990)	Top-5 Accuracy 70.889 (71.683)
# Epoch: [29][14900/17702]	Batch Time 0.449 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.5028 (3.3992)	Top-5 Accuracy 73.641 (71.680)
# Epoch: [29][15000/17702]	Batch Time 0.419 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.4649 (3.3993)	Top-5 Accuracy 70.055 (71.679)
# Epoch: [29][15100/17702]	Batch Time 0.498 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2772 (3.3994)	Top-5 Accuracy 70.350 (71.678)
# Epoch: [29][15200/17702]	Batch Time 0.498 (0.468)	Data Load Time 0.018 (0.005)	Loss 3.4402 (3.3995)	Top-5 Accuracy 71.507 (71.676)
# Epoch: [29][15300/17702]	Batch Time 0.447 (0.468)	Data Load Time 0.001 (0.005)	Loss 3.2767 (3.3996)	Top-5 Accuracy 73.846 (71.675)
# Epoch: [29][15400/17702]	Batch Time 0.499 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.4161 (3.3998)	Top-5 Accuracy 69.315 (71.671)
# Epoch: [29][15500/17702]	Batch Time 0.483 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.5266 (3.4000)	Top-5 Accuracy 70.833 (71.670)
# Epoch: [29][15600/17702]	Batch Time 0.532 (0.469)	Data Load Time 0.020 (0.005)	Loss 3.6990 (3.4003)	Top-5 Accuracy 70.083 (71.665)
# Epoch: [29][15700/17702]	Batch Time 0.409 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.5366 (3.4003)	Top-5 Accuracy 67.480 (71.665)
# Epoch: [29][15800/17702]	Batch Time 0.504 (0.469)	Data Load Time 0.014 (0.005)	Loss 3.5232 (3.4003)	Top-5 Accuracy 69.653 (71.666)
# Epoch: [29][15900/17702]	Batch Time 0.408 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.5152 (3.4004)	Top-5 Accuracy 71.279 (71.665)
# Epoch: [29][16000/17702]	Batch Time 0.439 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.1669 (3.4005)	Top-5 Accuracy 73.654 (71.665)
# Epoch: [29][16100/17702]	Batch Time 0.442 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.4769 (3.4008)	Top-5 Accuracy 72.826 (71.660)
# Epoch: [29][16200/17702]	Batch Time 0.408 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.5597 (3.4011)	Top-5 Accuracy 68.802 (71.658)
# Epoch: [29][16300/17702]	Batch Time 0.383 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.2654 (3.4011)	Top-5 Accuracy 74.194 (71.658)
# Epoch: [29][16400/17702]	Batch Time 0.424 (0.469)	Data Load Time 0.014 (0.005)	Loss 3.2371 (3.4013)	Top-5 Accuracy 73.699 (71.656)
# Epoch: [29][16500/17702]	Batch Time 0.483 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.4036 (3.4014)	Top-5 Accuracy 71.990 (71.654)
# Epoch: [29][16600/17702]	Batch Time 0.533 (0.469)	Data Load Time 0.014 (0.005)	Loss 3.2110 (3.4015)	Top-5 Accuracy 75.202 (71.655)
# Epoch: [29][16700/17702]	Batch Time 0.520 (0.469)	Data Load Time 0.008 (0.005)	Loss 3.3489 (3.4017)	Top-5 Accuracy 73.298 (71.654)
# Epoch: [29][16800/17702]	Batch Time 0.436 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.5960 (3.4017)	Top-5 Accuracy 69.505 (71.652)
# Epoch: [29][16900/17702]	Batch Time 0.419 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.6597 (3.4019)	Top-5 Accuracy 68.219 (71.649)
# Epoch: [29][17000/17702]	Batch Time 0.452 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.4847 (3.4020)	Top-5 Accuracy 72.995 (71.648)
# Epoch: [29][17100/17702]	Batch Time 0.609 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.2193 (3.4023)	Top-5 Accuracy 74.599 (71.645)
# Epoch: [29][17200/17702]	Batch Time 0.420 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.1146 (3.4024)	Top-5 Accuracy 76.230 (71.645)
# Epoch: [29][17300/17702]	Batch Time 0.380 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.4635 (3.4025)	Top-5 Accuracy 70.769 (71.643)
# Epoch: [29][17400/17702]	Batch Time 0.412 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.3540 (3.4027)	Top-5 Accuracy 74.432 (71.641)
# Epoch: [29][17500/17702]	Batch Time 0.502 (0.469)	Data Load Time 0.014 (0.005)	Loss 3.4599 (3.4030)	Top-5 Accuracy 72.253 (71.638)
# Epoch: [29][17600/17702]	Batch Time 0.485 (0.469)	Data Load Time 0.002 (0.005)	Loss 3.5703 (3.4031)	Top-5 Accuracy 69.452 (71.636)
# Epoch: [29][17700/17702]	Batch Time 0.424 (0.469)	Data Load Time 0.001 (0.005)	Loss 3.5735 (3.4033)	Top-5 Accuracy 71.117 (71.633)
# Validation: [0/782]	Batch Time 1.148 (1.148)	Loss 4.2663 (4.2663)	Top-5 Accuracy 65.546 (65.546)
# Validation: [100/782]	Batch Time 0.299 (0.333)	Loss 3.6377 (3.7161)	Top-5 Accuracy 68.750 (68.902)
# Validation: [200/782]	Batch Time 0.376 (0.330)	Loss 3.6351 (3.7256)	Top-5 Accuracy 68.407 (68.737)
# Validation: [300/782]	Batch Time 0.328 (0.328)	Loss 3.8888 (3.7383)	Top-5 Accuracy 65.706 (68.645)
# Validation: [400/782]	Batch Time 0.339 (0.326)	Loss 3.4702 (3.7371)	Top-5 Accuracy 70.868 (68.669)
# Validation: [500/782]	Batch Time 0.299 (0.326)	Loss 3.5891 (3.7366)	Top-5 Accuracy 68.698 (68.604)
# Validation: [600/782]	Batch Time 0.302 (0.326)	Loss 3.5558 (3.7310)	Top-5 Accuracy 68.715 (68.653)
# Validation: [700/782]	Batch Time 0.326 (0.325)	Loss 3.7868 (3.7289)	Top-5 Accuracy 65.922 (68.678)
#
#  * LOSS - 3.732, TOP-5 ACCURACY - 68.647, BLEU-4 - 0.1459767484273001
#
#
# Epochs since last improvement: 6
#
# ...
# Epoch: [32][2100/17702]	Batch Time 0.410 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.5647 (3.3472)	Top-5 Accuracy 69.421 (72.255)
# Epoch: [32][2200/17702]	Batch Time 0.409 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.5132 (3.3477)	Top-5 Accuracy 70.506 (72.235)
# Epoch: [32][2300/17702]	Batch Time 0.415 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.2976 (3.3476)	Top-5 Accuracy 73.121 (72.244)
# Epoch: [32][2400/17702]	Batch Time 0.438 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.5217 (3.3482)	Top-5 Accuracy 70.145 (72.233)
# Epoch: [32][2500/17702]	Batch Time 0.406 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.2402 (3.3487)	Top-5 Accuracy 72.853 (72.232)
# Epoch: [32][2600/17702]	Batch Time 0.445 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.2468 (3.3485)	Top-5 Accuracy 74.425 (72.234)
# Epoch: [32][2700/17702]	Batch Time 0.399 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.2874 (3.3491)	Top-5 Accuracy 72.829 (72.229)
# Epoch: [32][2800/17702]	Batch Time 0.591 (0.471)	Data Load Time 0.014 (0.005)	Loss 3.3294 (3.3498)	Top-5 Accuracy 73.421 (72.219)
# Epoch: [32][2900/17702]	Batch Time 0.531 (0.472)	Data Load Time 0.014 (0.005)	Loss 3.1424 (3.3489)	Top-5 Accuracy 75.204 (72.228)
# Epoch: [32][3000/17702]	Batch Time 0.391 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.3982 (3.3495)	Top-5 Accuracy 71.549 (72.216)
# Epoch: [32][3100/17702]	Batch Time 0.498 (0.472)	Data Load Time 0.013 (0.005)	Loss 3.4429 (3.3499)	Top-5 Accuracy 70.752 (72.210)
# Epoch: [32][3200/17702]	Batch Time 0.440 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.4755 (3.3492)	Top-5 Accuracy 72.603 (72.213)
# Epoch: [32][3300/17702]	Batch Time 0.393 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.2684 (3.3492)	Top-5 Accuracy 73.442 (72.214)
# Epoch: [32][3400/17702]	Batch Time 0.423 (0.472)	Data Load Time 0.015 (0.005)	Loss 3.3079 (3.3495)	Top-5 Accuracy 71.545 (72.207)
# Epoch: [32][3500/17702]	Batch Time 0.480 (0.472)	Data Load Time 0.014 (0.005)	Loss 3.1920 (3.3490)	Top-5 Accuracy 75.405 (72.213)
# Epoch: [32][3600/17702]	Batch Time 0.496 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.4521 (3.3493)	Top-5 Accuracy 71.684 (72.210)
# Epoch: [32][3700/17702]	Batch Time 0.450 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.3345 (3.3492)	Top-5 Accuracy 72.222 (72.210)
# Epoch: [32][3800/17702]	Batch Time 0.584 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.5148 (3.3493)	Top-5 Accuracy 68.378 (72.202)
# Epoch: [32][3900/17702]	Batch Time 0.511 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.1511 (3.3492)	Top-5 Accuracy 72.074 (72.202)
# Epoch: [32][4000/17702]	Batch Time 0.417 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.3002 (3.3491)	Top-5 Accuracy 72.678 (72.200)
# Epoch: [32][4100/17702]	Batch Time 0.430 (0.472)	Data Load Time 0.023 (0.005)	Loss 3.4036 (3.3496)	Top-5 Accuracy 73.514 (72.190)
# Epoch: [32][4200/17702]	Batch Time 0.542 (0.472)	Data Load Time 0.001 (0.005)	Loss 3.2378 (3.3501)	Top-5 Accuracy 74.074 (72.191)
# Epoch: [32][4300/17702]	Batch Time 0.536 (0.472)	Data Load Time 0.012 (0.005)	Loss 3.3188 (3.3496)	Top-5 Accuracy 71.979 (72.202)
# Epoch: [32][4400/17702]	Batch Time 0.424 (0.471)	Data Load Time 0.025 (0.005)	Loss 3.4074 (3.3496)	Top-5 Accuracy 70.349 (72.199)
# Epoch: [32][4500/17702]	Batch Time 0.500 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2502 (3.3496)	Top-5 Accuracy 72.727 (72.197)
# Epoch: [32][4600/17702]	Batch Time 0.470 (0.471)	Data Load Time 0.014 (0.005)	Loss 3.3819 (3.3497)	Top-5 Accuracy 75.405 (72.193)
# Epoch: [32][4700/17702]	Batch Time 0.434 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3038 (3.3503)	Top-5 Accuracy 72.905 (72.180)
# Epoch: [32][4800/17702]	Batch Time 0.481 (0.471)	Data Load Time 0.014 (0.005)	Loss 3.4255 (3.3512)	Top-5 Accuracy 70.231 (72.167)
# Epoch: [32][4900/17702]	Batch Time 0.474 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.4078 (3.3513)	Top-5 Accuracy 69.022 (72.165)
# Epoch: [32][5000/17702]	Batch Time 0.449 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3638 (3.3513)	Top-5 Accuracy 71.504 (72.163)
# Epoch: [32][5100/17702]	Batch Time 0.474 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.4238 (3.3508)	Top-5 Accuracy 71.585 (72.170)
# Epoch: [32][5200/17702]	Batch Time 0.398 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.4596 (3.3507)	Top-5 Accuracy 69.086 (72.172)
# Epoch: [32][5300/17702]	Batch Time 0.537 (0.471)	Data Load Time 0.013 (0.005)	Loss 3.5018 (3.3510)	Top-5 Accuracy 69.496 (72.164)
# Epoch: [32][5400/17702]	Batch Time 0.444 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3064 (3.3512)	Top-5 Accuracy 70.411 (72.159)
# Epoch: [32][5500/17702]	Batch Time 0.452 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2083 (3.3512)	Top-5 Accuracy 74.615 (72.158)
# Epoch: [32][5600/17702]	Batch Time 0.407 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.2162 (3.3513)	Top-5 Accuracy 72.702 (72.156)
# Epoch: [32][5700/17702]	Batch Time 0.473 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2920 (3.3511)	Top-5 Accuracy 71.642 (72.156)
# Epoch: [32][5800/17702]	Batch Time 0.513 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.2777 (3.3511)	Top-5 Accuracy 73.757 (72.154)
# Epoch: [32][5900/17702]	Batch Time 0.413 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.1823 (3.3512)	Top-5 Accuracy 74.114 (72.152)
# Epoch: [32][6000/17702]	Batch Time 0.434 (0.470)	Data Load Time 0.014 (0.005)	Loss 3.2875 (3.3508)	Top-5 Accuracy 73.407 (72.158)
# Epoch: [32][6100/17702]	Batch Time 0.532 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.2347 (3.3510)	Top-5 Accuracy 73.280 (72.157)
# Epoch: [32][6200/17702]	Batch Time 0.436 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2560 (3.3512)	Top-5 Accuracy 71.429 (72.152)
# Epoch: [32][6300/17702]	Batch Time 0.462 (0.470)	Data Load Time 0.013 (0.005)	Loss 3.3519 (3.3510)	Top-5 Accuracy 72.533 (72.156)
# Epoch: [32][6400/17702]	Batch Time 0.505 (0.470)	Data Load Time 0.014 (0.005)	Loss 3.5065 (3.3510)	Top-5 Accuracy 70.652 (72.156)
# Epoch: [32][6500/17702]	Batch Time 0.484 (0.470)	Data Load Time 0.010 (0.005)	Loss 3.4237 (3.3515)	Top-5 Accuracy 71.117 (72.152)
# Epoch: [32][6600/17702]	Batch Time 0.434 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.5032 (3.3518)	Top-5 Accuracy 68.889 (72.149)
# Epoch: [32][6700/17702]	Batch Time 0.481 (0.470)	Data Load Time 0.016 (0.005)	Loss 3.3591 (3.3521)	Top-5 Accuracy 70.655 (72.147)
# Epoch: [32][6800/17702]	Batch Time 0.405 (0.470)	Data Load Time 0.005 (0.005)	Loss 3.3732 (3.3523)	Top-5 Accuracy 70.556 (72.142)
# Epoch: [32][6900/17702]	Batch Time 0.438 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.2879 (3.3523)	Top-5 Accuracy 74.247 (72.145)
# Epoch: [32][7000/17702]	Batch Time 0.432 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.3372 (3.3524)	Top-5 Accuracy 72.727 (72.144)
# Epoch: [32][7100/17702]	Batch Time 0.490 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.2987 (3.3526)	Top-5 Accuracy 73.046 (72.143)
# Epoch: [32][7200/17702]	Batch Time 0.502 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.2100 (3.3527)	Top-5 Accuracy 75.676 (72.141)
# Epoch: [32][7300/17702]	Batch Time 0.514 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3454 (3.3526)	Top-5 Accuracy 73.025 (72.145)
# Epoch: [32][7400/17702]	Batch Time 0.549 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.5744 (3.3527)	Top-5 Accuracy 68.351 (72.142)
# Epoch: [32][7500/17702]	Batch Time 0.516 (0.471)	Data Load Time 0.014 (0.005)	Loss 3.2847 (3.3529)	Top-5 Accuracy 72.423 (72.140)
# Epoch: [32][7600/17702]	Batch Time 0.482 (0.471)	Data Load Time 0.014 (0.005)	Loss 3.5312 (3.3531)	Top-5 Accuracy 69.832 (72.140)
# Epoch: [32][7700/17702]	Batch Time 0.462 (0.471)	Data Load Time 0.014 (0.005)	Loss 3.1094 (3.3535)	Top-5 Accuracy 74.419 (72.138)
# Epoch: [32][7800/17702]	Batch Time 0.402 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3954 (3.3539)	Top-5 Accuracy 71.637 (72.137)
# Epoch: [32][7900/17702]	Batch Time 0.432 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.4353 (3.3542)	Top-5 Accuracy 70.572 (72.134)
# Epoch: [32][8000/17702]	Batch Time 0.405 (0.471)	Data Load Time 0.026 (0.005)	Loss 3.5587 (3.3542)	Top-5 Accuracy 70.482 (72.134)
# Epoch: [32][8100/17702]	Batch Time 0.507 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.4698 (3.3541)	Top-5 Accuracy 72.135 (72.134)
# Epoch: [32][8200/17702]	Batch Time 0.473 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3612 (3.3546)	Top-5 Accuracy 71.111 (72.131)
# Epoch: [32][8300/17702]	Batch Time 0.405 (0.471)	Data Load Time 0.014 (0.005)	Loss 3.2527 (3.3547)	Top-5 Accuracy 71.667 (72.129)
# Epoch: [32][8400/17702]	Batch Time 0.511 (0.471)	Data Load Time 0.006 (0.005)	Loss 3.3821 (3.3546)	Top-5 Accuracy 71.196 (72.128)
# Epoch: [32][8500/17702]	Batch Time 0.439 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.4588 (3.3550)	Top-5 Accuracy 72.334 (72.126)
# Epoch: [32][8600/17702]	Batch Time 0.471 (0.471)	Data Load Time 0.015 (0.005)	Loss 3.0938 (3.3551)	Top-5 Accuracy 73.867 (72.124)
# Epoch: [32][8700/17702]	Batch Time 0.423 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.5373 (3.3552)	Top-5 Accuracy 72.823 (72.123)
# Epoch: [32][8800/17702]	Batch Time 0.443 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3232 (3.3554)	Top-5 Accuracy 73.067 (72.121)
# Epoch: [32][8900/17702]	Batch Time 0.461 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.5044 (3.3556)	Top-5 Accuracy 69.253 (72.119)
# Epoch: [32][9000/17702]	Batch Time 0.414 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.4195 (3.3558)	Top-5 Accuracy 73.729 (72.115)
# Epoch: [32][9100/17702]	Batch Time 0.436 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.5268 (3.3559)	Top-5 Accuracy 70.055 (72.113)
# Epoch: [32][9200/17702]	Batch Time 0.442 (0.471)	Data Load Time 0.013 (0.005)	Loss 3.1236 (3.3561)	Top-5 Accuracy 74.309 (72.110)
# Epoch: [32][9300/17702]	Batch Time 0.446 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3540 (3.3561)	Top-5 Accuracy 70.704 (72.110)
# Epoch: [32][9400/17702]	Batch Time 0.399 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.2766 (3.3564)	Top-5 Accuracy 72.881 (72.108)
# Epoch: [32][9500/17702]	Batch Time 0.412 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.3203 (3.3566)	Top-5 Accuracy 74.656 (72.105)
# Epoch: [32][9600/17702]	Batch Time 0.460 (0.470)	Data Load Time 0.014 (0.005)	Loss 3.2707 (3.3566)	Top-5 Accuracy 76.816 (72.106)
# Epoch: [32][9700/17702]	Batch Time 0.590 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.5194 (3.3565)	Top-5 Accuracy 71.625 (72.106)
# Epoch: [32][9800/17702]	Batch Time 0.580 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.4802 (3.3567)	Top-5 Accuracy 72.193 (72.106)
# Epoch: [32][9900/17702]	Batch Time 0.446 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.6226 (3.3569)	Top-5 Accuracy 67.568 (72.104)
# Epoch: [32][10000/17702]	Batch Time 0.461 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.3200 (3.3570)	Top-5 Accuracy 74.332 (72.104)
# Epoch: [32][10100/17702]	Batch Time 0.569 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.5072 (3.3569)	Top-5 Accuracy 71.467 (72.107)
# Epoch: [32][10200/17702]	Batch Time 0.648 (0.470)	Data Load Time 0.014 (0.005)	Loss 3.3208 (3.3568)	Top-5 Accuracy 72.559 (72.107)
# Epoch: [32][10300/17702]	Batch Time 0.501 (0.470)	Data Load Time 0.019 (0.005)	Loss 3.2763 (3.3571)	Top-5 Accuracy 74.033 (72.104)
# Epoch: [32][10400/17702]	Batch Time 0.403 (0.470)	Data Load Time 0.013 (0.005)	Loss 3.1245 (3.3571)	Top-5 Accuracy 74.336 (72.103)
# Epoch: [32][10500/17702]	Batch Time 0.519 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.1862 (3.3572)	Top-5 Accuracy 73.204 (72.103)
# Epoch: [32][10600/17702]	Batch Time 0.585 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.2979 (3.3574)	Top-5 Accuracy 70.833 (72.101)
# Epoch: [32][10700/17702]	Batch Time 0.404 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.2375 (3.3577)	Top-5 Accuracy 75.209 (72.098)
# Epoch: [32][10800/17702]	Batch Time 0.503 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.2367 (3.3577)	Top-5 Accuracy 73.098 (72.099)
# Epoch: [32][10900/17702]	Batch Time 0.416 (0.471)	Data Load Time 0.013 (0.005)	Loss 3.3244 (3.3577)	Top-5 Accuracy 72.460 (72.099)
# Epoch: [32][11000/17702]	Batch Time 0.444 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.3549 (3.3579)	Top-5 Accuracy 71.508 (72.097)
# Epoch: [32][11100/17702]	Batch Time 0.557 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.2703 (3.3580)	Top-5 Accuracy 73.791 (72.097)
# Epoch: [32][11200/17702]	Batch Time 0.469 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3213 (3.3582)	Top-5 Accuracy 74.084 (72.096)
# Epoch: [32][11300/17702]	Batch Time 0.447 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3764 (3.3584)	Top-5 Accuracy 72.752 (72.093)
# Epoch: [32][11400/17702]	Batch Time 0.467 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.1901 (3.3584)	Top-5 Accuracy 75.573 (72.095)
# Epoch: [32][11500/17702]	Batch Time 0.405 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.5159 (3.3587)	Top-5 Accuracy 71.271 (72.092)
# Epoch: [32][11600/17702]	Batch Time 0.432 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.1227 (3.3588)	Top-5 Accuracy 75.214 (72.091)
# Epoch: [32][11700/17702]	Batch Time 0.517 (0.471)	Data Load Time 0.023 (0.005)	Loss 3.1363 (3.3588)	Top-5 Accuracy 73.713 (72.091)
# Epoch: [32][11800/17702]	Batch Time 0.440 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3292 (3.3589)	Top-5 Accuracy 71.809 (72.091)
# Epoch: [32][11900/17702]	Batch Time 0.474 (0.471)	Data Load Time 0.012 (0.005)	Loss 3.3942 (3.3591)	Top-5 Accuracy 71.910 (72.087)
# Epoch: [32][12000/17702]	Batch Time 0.444 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3914 (3.3590)	Top-5 Accuracy 71.858 (72.086)
# Epoch: [32][12100/17702]	Batch Time 0.436 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2665 (3.3592)	Top-5 Accuracy 72.194 (72.084)
# Epoch: [32][12200/17702]	Batch Time 0.438 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.5421 (3.3593)	Top-5 Accuracy 66.404 (72.085)
# Epoch: [32][12300/17702]	Batch Time 0.490 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3897 (3.3597)	Top-5 Accuracy 73.190 (72.081)
# Epoch: [32][12400/17702]	Batch Time 0.443 (0.470)	Data Load Time 0.011 (0.005)	Loss 3.2178 (3.3598)	Top-5 Accuracy 73.901 (72.080)
# Epoch: [32][12500/17702]	Batch Time 0.518 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.3233 (3.3599)	Top-5 Accuracy 73.087 (72.078)
# Epoch: [32][12600/17702]	Batch Time 0.430 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.5023 (3.3601)	Top-5 Accuracy 69.657 (72.075)
# Epoch: [32][12700/17702]	Batch Time 0.474 (0.470)	Data Load Time 0.001 (0.005)	Loss 3.4290 (3.3602)	Top-5 Accuracy 72.165 (72.075)
# Epoch: [32][12800/17702]	Batch Time 0.405 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.5367 (3.3602)	Top-5 Accuracy 69.318 (72.075)
# Epoch: [32][12900/17702]	Batch Time 0.433 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.1987 (3.3604)	Top-5 Accuracy 74.157 (72.074)
# Epoch: [32][13000/17702]	Batch Time 0.453 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.4737 (3.3607)	Top-5 Accuracy 68.733 (72.070)
# Epoch: [32][13100/17702]	Batch Time 0.456 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2251 (3.3607)	Top-5 Accuracy 75.134 (72.068)
# Epoch: [32][13200/17702]	Batch Time 0.439 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.5059 (3.3608)	Top-5 Accuracy 70.509 (72.066)
# Epoch: [32][13300/17702]	Batch Time 0.458 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2996 (3.3609)	Top-5 Accuracy 73.243 (72.068)
# Epoch: [32][13400/17702]	Batch Time 0.482 (0.471)	Data Load Time 0.013 (0.005)	Loss 3.2870 (3.3612)	Top-5 Accuracy 74.670 (72.063)
# Epoch: [32][13500/17702]	Batch Time 0.431 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.3365 (3.3612)	Top-5 Accuracy 70.739 (72.065)
# Epoch: [32][13600/17702]	Batch Time 0.522 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2464 (3.3613)	Top-5 Accuracy 74.202 (72.064)
# Epoch: [32][13700/17702]	Batch Time 0.489 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2821 (3.3616)	Top-5 Accuracy 73.256 (72.058)
# Epoch: [32][13800/17702]	Batch Time 0.631 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2871 (3.3618)	Top-5 Accuracy 71.582 (72.055)
# Epoch: [32][13900/17702]	Batch Time 0.392 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2271 (3.3620)	Top-5 Accuracy 73.043 (72.053)
# Epoch: [32][14000/17702]	Batch Time 0.373 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.2808 (3.3620)	Top-5 Accuracy 72.303 (72.052)
# Epoch: [32][14100/17702]	Batch Time 0.433 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.4640 (3.3621)	Top-5 Accuracy 72.099 (72.051)
# Epoch: [32][14200/17702]	Batch Time 0.582 (0.471)	Data Load Time 0.001 (0.005)	Loss 3.1121 (3.3621)	Top-5 Accuracy 76.087 (72.050)
